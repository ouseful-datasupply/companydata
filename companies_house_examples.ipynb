# %% [markdown]
# # Companies House Examples
#
# Examples of grabbing Companies House data.

# %%
import os
#os.environ["CH_API_KEY"] = ...
CH_API_KEY = os.environ["CH_API_KEY"]

# %%
from ouseful_companydata.companies_house import CompaniesHouseAPI

ch_api = CompaniesHouseAPI(CH_API_KEY, use_cache=True)
# Out:
# Database created.
# Creating database tables.
# Caching enabled with sqlite backend: companies_house_cache

# %%
ch_api.ch_search_companies("Formula One")
# Out:
# {'start_index': 0,
#  'total_results': 39726,
#  'items': [{'company_number': '04202765',
#    'description': '04202765 - Incorporated on 20 April 2001',
#    'address': {'postal_code': 'SW1Y 4AH',
#     'locality': 'London',
#     'country': 'United Kingdom',
#     'address_line_1': "No. 2 St. James's Market"},
#    'company_type': 'ltd',
#    'address_snippet': "No. 2 St. James's Market, London, United Kingdom, SW1Y 4AH",
#    'description_identifier': ['incorporated-on'],
#    'snippet': '',
#    'links': {'self': '/company/04202765'},
#    'kind': 'searchresults#company',
#    'matches': {'snippet': []},
#    'title': 'FORMULA ONE LIMITED',
#    'company_status': 'active',
#    'date_of_creation': '2001-04-20'},
#   {'address_snippet': "No. 2 St. James's Market, London, United Kingdom, SW1Y 4AH",
#    'address': {'address_line_1': "No. 2 St. James's Market",
#     'country': 'United Kingdom',
#     'postal_code': 'SW1Y 4AH',
#     'locality': 'London'},
# ...

# %%
ch_api.ch_searchOfficers("Bernard Ecclestone")
# Out:
# {'items_per_page': 50,
#  'page_number': 1,
#  'start_index': 0,
#  'total_results': 13752,
#  'items': [{'matches': {'snippet': []},
#    'description_identifiers': ['appointment-count'],
#    'description': 'Total number of appointments 1',
#    'kind': 'searchresults#officer',
#    'address_snippet': '27 Mortimer Street, London, United Kingdom, W1T 3BL',
#    'title': 'Bernard Charles ECCLESTONE',
#    'links': {'self': '/officers/8UfUmkQjd9G_7buutn71Z1jJNgY/appointments'},
#    'address': {'address_line_1': 'Mortimer Street',
#     'postal_code': 'W1T 3BL',
#     'country': 'United Kingdom',
#     'premises': '27',
#     'locality': 'London'},
#    'snippet': '',
#    'appointment_count': 1},
#   {'description_identifiers': ['appointment-count'],
#    'matches': {'snippet': []},
#    'description': 'Total number of appointments 1',
#    'title': 'Bernard Charles ECCLESTONE',
#    'address_snippet': '27 Mortimer Street, London, England, W1T 3BL',
# ...

# %%
ch_api.ch_searchDisQualifiedOfficers("Smith", 3)
# Out:
# {'kind': 'search#disqualified-officers',
#  'total_results': 60,
#  'items': [{'links': {'self': '/disqualified-officers/natural/b9kFokaoiN4WU4aOe7P5Vw-iFgg'},
#    'snippet': '',
#    'description': 'Born on 20 March 1974 - Disqualified',
#    'matches': {'snippet': []},
#    'date_of_birth': '1974-03-20T00:00:00',
#    'description_identifiers': ['born-on'],
#    'title': 'Alister Edward SMITH',
#    'address_snippet': '10 Barn Croft Drive, Lower Earley, Reading, United Kingdom, RG6 3WE',
#    'kind': 'searchresults#disqualified-officer',
#    'address': {'postal_code': 'RG6 3WE',
#     'address_line_2': 'Lower Earley',
#     'locality': 'Reading',
#     'premises': '10',
#     'country': 'United Kingdom',
#     'address_line_1': 'Barn Croft Drive'}},
#   {'date_of_birth': '1997-09-15T00:00:00',
#    'matches': {'snippet': []},
#    'snippet': '',
#    'description': 'Born on 15 September 1997 - Disqualified',
# ...

# %%
ch_api.ch_getCompanyOfficers("04202765")
# Out:
# {'active_count': 1,
#  'etag': '2ad4ed167afc857cc4ce09e968b8a4441a50d350',
#  'items': [{'address': {'address_line_1': "St. James's Market",
#     'country': 'United Kingdom',
#     'locality': 'London',
#     'postal_code': 'SW1Y 4AH',
#     'premises': 'No. 2'},
#    'appointed_on': '2003-04-30',
#    'is_pre_1992_appointment': False,
#    'country_of_residence': 'United Kingdom',
#    'date_of_birth': {'month': 4, 'year': 1968},
#    'links': {'self': '/company/04202765/appointments/oAbHwkAhShEhh_7_LLb25Y4miyU',
#     'officer': {'appointments': '/officers/dzIMC8ot_A9rJThNdKQ5yQC-M3Y/appointments'}},
#    'name': 'LLOWARCH, Duncan Francis',
#    'nationality': 'British',
#    'occupation': 'Accountant',
#    'officer_role': 'director',
#    'person_number': '133291230002'},
#   {'address': {'address_line_1': "St. James's Market",
#     'country': 'United Kingdom',
#     'locality': 'London',
#     'postal_code': 'SW1Y 4AH',
#     'premises': 'No. 2'},
# ...

# %%
dirseeds, companyseeds = ch_api.get_dirSeedsCompanySeeds("Simon James Moran")
dirseeds, companyseeds
# Out:
# (['/officers/myrTw63DbawX8UgHew9zZJkvTsY/appointments',
#   '/officers/GM2UNL5OteT0dEVOGPDvejst2BA/appointments'],
#  ['15312528',
#   '14288642',
#   '11855947',
#   '10298216',
#   '08775997',
#   '08765740',
#   '08599387',
#   '08610539',
#   'SC333566',
#   '06608734',
#   '06408364',
#   '05141419',
#   '03463738',
#   '03902025',
#   '03683966',
#   '02530904',
#   '03130736',
#   '02686954'])

# %%
c = ch_api.db.cursor()
c.execute("SELECT * FROM companieslite")
[row for row in c.fetchall()]
# Out:
# []

# %%
company_record = ch_api.ch_getCompany("15312528")
company_record
# Out:
# {'accounts': {'accounting_reference_date': {'day': '30', 'month': '11'},
#   'next_accounts': {'due_on': '2025-08-28',
#    'overdue': False,
#    'period_end_on': '2024-11-30',
#    'period_start_on': '2023-11-28'},
#   'next_due': '2025-08-28',
#   'next_made_up_to': '2024-11-30',
#   'overdue': False},
#  'can_file': True,
#  'company_name': 'CAPITAL & CENTRIC (RUSH HOLDCO) LTD',
#  'company_number': '15312528',
#  'company_status': 'active',
#  'confirmation_statement': {'last_made_up_to': '2024-11-27',
#   'next_due': '2025-12-11',
#   'next_made_up_to': '2025-11-27',
#   'overdue': False},
#  'date_of_creation': '2023-11-28',
#  'etag': '8652f7f7cef86cd70c0b2df8fb86dc72424c0d84',
#  'has_charges': False,
#  'has_insolvency_history': False,
#  'jurisdiction': 'england-wales',
#  'links': {'persons_with_significant_control': '/company/15312528/persons-with-significant-control',
#   'self': '/company/15312528',
#   'charges': '/company/15312528/charges',
# ...

# %%
ch_api.get_psc(company_record)
# Out:
# ('CAPITAL & CENTRIC (RUSH HOLDCO) LTD',
#  '15312528',
#  '/company/15312528/persons-with-significant-control')

# %%
ch_api.get_director_company_data("Simon James Moran")
# Out:
# harvesting 15312528
# Adding 5 directors
# New director: lzEf32UL_iJzuYNU8-KXBswDsW4
# Adding 31 companies
# Adding 31 company-directorships
# New director: xWYlDvWGAbbOAPkYvvKIZSid82c
# Adding 13 companies
# Adding 29 company-directorships
# New director: n-YrZce0gPbaPnm-zld51-_m700
# Adding 2 companies
# Adding 18 company-directorships
# New director: myrTw63DbawX8UgHew9zZJkvTsY
# Adding 18 companies
# Adding 21 company-directorships
# New director: q1O3m-MV9GvTYCx-4Kb1MuAyjYQ
# Adding 1 companies
# Adding 16 company-directorships
# harvesting 14288642
# Adding 3 directors
# New director: Umno1dnEN5khOaBXP3z8esdtHxk
# Adding 3 companies
# Adding 17 company-directorships
# New director: Q5wBYiQTuSOubzqNMVGs_Gw9sp8
# Adding 0 companies
# Adding 1 company-directorships
# New director: slXW4uPxtm9mCNFMp8qrFv7fZ3M
# Adding 0 companies
# Adding 1 company-directorships
# harvesting 11855947
# Adding 0 directors
# harvesting 10298216
# Adding 6 directors
# ...

# %%
G = ch_api.generate_nx_model()

# %%
ch_api.visualise_network(G)

# %%
ch_api.co_director_trawler()
# Out:
# ---------------
# Filling out level - 0...
# ...

# %%
G2 = ch_api.generate_nx_model()
ch_api.visualise_network(G2)
